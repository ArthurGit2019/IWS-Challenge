# %% [markdown]
# # Get Plant A 2002 - 2010 Raw Data

# %%
import pandas as pd
import numpy as np

plantA_Raw = pd.read_excel('Downloads/2022 - IWS - Sample Topic 1 data/Plant A Raw 2001- 2010.xls', 
                           sheet_name=[2, 3, 4, 5, 6, 7, 8, 9], names=["Date", "pH", "BOD5", "TS", "SS", "TKN", "NH3-N", 
                                                                       "NO2-N", "NO3-N", "P-TOT", "P-SOL", "Cl", "F","FOG", 
                                                                       "Phenol-Man", "SO4", "CN (COMP)", "CN (GRAB)", 
                                                                       "CN_WAD", "As", "Ba", "Cd", "Cr", "Cu", "Fe", 
                                                                       "Fe(SOL)", "Pb", "Mn", "Hg", "Ni", "Se", "Ag", "Zn", 
                                                                       "Sb", "Be", "Tl", "Cr6", "As Sol", "Ba Sol", 
                                                                       "Cd Sol", "Cr Sol", "Cu Sol", "Pb Sol", "Mn Sol", 
                                                                       "Hg Sol", "Ni Sol", "Se Sol", "Ag Sol", "Zn Sol",
                                                                       "Sb Sol", "Be Sol", "Tl Sol"], 
                           skiprows=range(1,3), nrows=365, na_values=['N/S', 'N/R'])
plantA_Raw_data = pd.concat(plantA_Raw, axis=0, ignore_index=True)
plantA_Raw_data
# Out:
#            Date   pH BOD5    TS   SS    TKN  NH3-N      NO2-N      NO3-N  \
# 0    2003-01-01  7.5  157   831  164   32.7  19.98       0.01      <0.03
# 1    2003-01-02  7.4  157   852  192   34.2  20.52      <0.01       0.04
# 2    2003-01-03  7.1  193   902  152   33.7  18.56       0.01       0.11
# 3    2003-01-04  7.4  218   902  204   33.1  20.13       0.03       0.34
# 4    2003-01-05  7.4  175   946  172   31.3  19.64       0.03      <0.03
# ...         ...  ...  ...   ...  ...    ...    ...        ...        ...
# 2915 2010-12-27  7.5  145  1094   96  32.63  23.04       0.14     <0.135
# 2916 2010-12-28  7.4  262  1163  326  36.82   23.0      0.081     <0.135
# 2917 2010-12-29  7.4  171  1008  182  31.32  21.51      0.039     <0.135
# 2918 2010-12-30  7.4  172  1317  226  26.98   16.3      0.091     <0.135
# 2919 2010-12-31  7.3   60  1236  126  14.41   6.66      0.554      1.158
#
#      P-TOT  ...    Pb Sol    Mn Sol    Hg Sol    Ni Sol    Se Sol    Ag Sol  \
# ...

# %%
plantA_Raw_2002 = pd.read_excel('Downloads/2022 - IWS - Sample Topic 1 data/Plant A Raw 2001- 2010.xls', sheet_name=1, 
                                names=["Date", "pH", "BOD5", "TS", "SS", "TKN", "NH3-N", "NO2-N", "NO3-N", "P-TOT", 
                                       "P-SOL", "CN_WAD", "Cl", "F","FOG", "Phenol-Man", "SO4", "CN (COMP)", "CN (GRAB)", 
                                       "As", "Ba", "Cd", "Cr", "Cu1", "Cu", "Fe", "Fe(SOL)", "Pb", "Mn", "Hg", "Ni", "Se", 
                                       "Ag", "Zn", "Sb", "Be", "Tl", "Cr6", "As Sol", "Ba Sol", "Cd Sol", "Cr Sol", 
                                       "Cu Sol", "Pb Sol", "Mn Sol", "Hg Sol", "Ni Sol", "Se Sol", "Ag Sol", "Zn Sol", 
                                       "Sb Sol", "Be Sol", "Tl Sol"], 
                                skiprows=range(1,3), nrows=365, na_values=['N/S', 'N/R'])
plantA_Raw_2002
# Out:
#           Date   pH  BOD5    TS   SS   TKN  NH3-N      NO2-N      NO3-N  \
# 0   2002-01-01  7.4   118   761  108  27.7  14.57       0.01      <0.03
# 1   2002-01-02  7.5   151   776  138  41.5  16.38       0.02      <0.03
# 2   2002-01-03  7.1   297  1064  354  41.7  17.61       0.03      <0.03
# 3   2002-01-04  7.1   230   921  176  35.1  15.93      <0.01       0.04
# 4   2002-01-05  7.0   204   895  154  33.7  16.14      <0.01       0.04
# ..         ...  ...   ...   ...  ...   ...    ...        ...        ...
# 360 2002-12-27  7.1   217  1000  264  33.3  16.31      <0.01       0.04
# 361 2002-12-28  7.4   144   807  108  25.2  15.01      <0.01       0.14
# 362 2002-12-29  7.4   204   977  284  31.1  14.19       0.02       0.04
# 363 2002-12-30  7.5   180   916  248  30.3  14.62      <0.01      <0.03
# 364 2002-12-31  7.0   143   883  184  29.2  16.94      <0.01       0.03
#
#      P-TOT  ...    Pb Sol    Mn Sol    Hg Sol    Ni Sol    Se Sol    Ag Sol  \
# ...

# %%
plantA_Raw_2002 = plantA_Raw_2002.drop(columns="Cu1")
plantA_Raw_2002 = plantA_Raw_2002[["Date", "pH", "BOD5", "TS", "SS", "TKN", "NH3-N", "NO2-N", "NO3-N", "P-TOT", "P-SOL", 
                                   "Cl", "F","FOG", "Phenol-Man", "SO4", "CN (COMP)", "CN (GRAB)", "CN_WAD", "As", "Ba", 
                                   "Cd", "Cr", "Cu", "Fe", "Fe(SOL)", "Pb", "Mn", "Hg", "Ni", "Se", "Ag", "Zn", "Sb", "Be", 
                                   "Tl", "Cr6", "As Sol", "Ba Sol", "Cd Sol", "Cr Sol", "Cu Sol", "Pb Sol", "Mn Sol", 
                                   "Hg Sol", "Ni Sol", "Se Sol", "Ag Sol", "Zn Sol", "Sb Sol", "Be Sol", "Tl Sol"]]
plantA_Raw_2002
# Out:
#           Date   pH  BOD5    TS   SS   TKN  NH3-N      NO2-N      NO3-N  \
# 0   2002-01-01  7.4   118   761  108  27.7  14.57       0.01      <0.03
# 1   2002-01-02  7.5   151   776  138  41.5  16.38       0.02      <0.03
# 2   2002-01-03  7.1   297  1064  354  41.7  17.61       0.03      <0.03
# 3   2002-01-04  7.1   230   921  176  35.1  15.93      <0.01       0.04
# 4   2002-01-05  7.0   204   895  154  33.7  16.14      <0.01       0.04
# ..         ...  ...   ...   ...  ...   ...    ...        ...        ...
# 360 2002-12-27  7.1   217  1000  264  33.3  16.31      <0.01       0.04
# 361 2002-12-28  7.4   144   807  108  25.2  15.01      <0.01       0.14
# 362 2002-12-29  7.4   204   977  284  31.1  14.19       0.02       0.04
# 363 2002-12-30  7.5   180   916  248  30.3  14.62      <0.01      <0.03
# 364 2002-12-31  7.0   143   883  184  29.2  16.94      <0.01       0.03
#
#      P-TOT  ...    Pb Sol    Mn Sol    Hg Sol    Ni Sol    Se Sol    Ag Sol  \
# ...

# %%
plantA_Raw_2002["CN_WAD"]
# Out:
# 0        0.0008
# 1           N/S
# 2           N/S
# 3           N/S
# 4           N/S
#          ...
# 360         N/S
# 361         N/S
# 362         N/S
# 363         N/S
# 364      0.0018
# Name: CN_WAD, Length: 365, dtype: object

# %%
plantA_raw_data = pd.concat([plantA_Raw_2002, plantA_Raw_data], axis=0, ignore_index=True)
plantA_raw_data
# Out:
#            Date   pH BOD5    TS   SS    TKN  NH3-N      NO2-N      NO3-N  \
# 0    2002-01-01  7.4  118   761  108   27.7  14.57       0.01      <0.03
# 1    2002-01-02  7.5  151   776  138   41.5  16.38       0.02      <0.03
# 2    2002-01-03  7.1  297  1064  354   41.7  17.61       0.03      <0.03
# 3    2002-01-04  7.1  230   921  176   35.1  15.93      <0.01       0.04
# 4    2002-01-05  7.0  204   895  154   33.7  16.14      <0.01       0.04
# ...         ...  ...  ...   ...  ...    ...    ...        ...        ...
# 3280 2010-12-27  7.5  145  1094   96  32.63  23.04       0.14     <0.135
# 3281 2010-12-28  7.4  262  1163  326  36.82   23.0      0.081     <0.135
# 3282 2010-12-29  7.4  171  1008  182  31.32  21.51      0.039     <0.135
# 3283 2010-12-30  7.4  172  1317  226  26.98   16.3      0.091     <0.135
# 3284 2010-12-31  7.3   60  1236  126  14.41   6.66      0.554      1.158
#
#      P-TOT  ...    Pb Sol    Mn Sol    Hg Sol    Ni Sol    Se Sol    Ag Sol  \
# ...

# %% [markdown]
# # Get Plant A 2002 - 2010 Flow Data

# %%
plantA_Flow = pd.read_excel('Downloads/2022 - IWS - Sample Topic 1 data/Plant A Flow_ 2001-2010.xls', 
                            sheet_name=[1, 2, 3, 4, 5, 6, 7, 8, 9], names=["Date", "FLOW MGD"], skiprows=range(1,3), 
                            nrows=365, na_values=['N/S', 'N/R'])

plantA_flow_data = pd.concat(plantA_Flow, axis=0, ignore_index=True)
plantA_flow_data
# Out:
#            Date  FLOW MGD
# 0    2002-01-01     23.42
# 1    2002-01-02     25.13
# 2    2002-01-03     25.65
# 3    2002-01-04     26.32
# 4    2002-01-05     23.94
# ...         ...       ...
# 3280 2010-12-27     22.58
# 3281 2010-12-28     22.68
# 3282 2010-12-29     22.28
# 3283 2010-12-30     32.18
# 3284 2010-12-31     84.55
#
# [3285 rows x 2 columns]

# %% [markdown]
# # Merge Flow Data and Raw Data

# %%
plantA_data = pd.merge(plantA_flow_data, plantA_raw_data, on="Date")
plantA_data
# Out:
#            Date  FLOW MGD   pH BOD5    TS   SS    TKN  NH3-N      NO2-N  \
# 0    2002-01-01     23.42  7.4  118   761  108   27.7  14.57       0.01
# 1    2002-01-02     25.13  7.5  151   776  138   41.5  16.38       0.02
# 2    2002-01-03     25.65  7.1  297  1064  354   41.7  17.61       0.03
# 3    2002-01-04     26.32  7.1  230   921  176   35.1  15.93      <0.01
# 4    2002-01-05     23.94  7.0  204   895  154   33.7  16.14      <0.01
# ...         ...       ...  ...  ...   ...  ...    ...    ...        ...
# 3280 2010-12-27     22.58  7.5  145  1094   96  32.63  23.04       0.14
# 3281 2010-12-28     22.68  7.4  262  1163  326  36.82   23.0      0.081
# 3282 2010-12-29     22.28  7.4  171  1008  182  31.32  21.51      0.039
# 3283 2010-12-30     32.18  7.4  172  1317  226  26.98   16.3      0.091
# 3284 2010-12-31     84.55  7.3   60  1236  126  14.41   6.66      0.554
#
#           NO3-N  ...    Pb Sol    Mn Sol    Hg Sol    Ni Sol    Se Sol  \
# ...

# %% [markdown]
# # Take a Quick Look at the Data Structure

# %%
plantA_data.head()
# Out:
#         Date  FLOW MGD   pH BOD5    TS   SS   TKN  NH3-N      NO2-N  \
# 0 2002-01-01     23.42  7.4  118   761  108  27.7  14.57       0.01
# 1 2002-01-02     25.13  7.5  151   776  138  41.5  16.38       0.02
# 2 2002-01-03     25.65  7.1  297  1064  354  41.7  17.61       0.03
# 3 2002-01-04     26.32  7.1  230   921  176  35.1  15.93      <0.01
# 4 2002-01-05     23.94  7.0  204   895  154  33.7  16.14      <0.01
#
#        NO3-N  ...    Pb Sol    Mn Sol    Hg Sol    Ni Sol    Se Sol    Ag Sol  \
# 0      <0.03  ...    <0.002    0.0445     <0.04     0.002     0.038    0.0006
# 1      <0.03  ...       N/S       N/S       N/S       N/S       N/S       N/S
# 2      <0.03  ...       N/S       N/S       N/S       N/S       N/S       N/S
# 3       0.04  ...       N/S       N/S       N/S       N/S       N/S       N/S
# 4       0.04  ...       N/S       N/S       N/S       N/S       N/S       N/S
#
#      Zn Sol    Sb Sol    Be Sol    Tl Sol
# 0     0.021    <0.004   <0.0002     <0.02
# ...

# %%
plantA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3285 entries, 0 to 3284
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        3285 non-null   datetime64[ns]
#  1   FLOW MGD    3285 non-null   float64
#  2   pH          3285 non-null   object
#  3   BOD5        3285 non-null   object
#  4   TS          3285 non-null   object
#  5   SS          3285 non-null   object
#  6   TKN         3285 non-null   object
#  7   NH3-N       3285 non-null   object
#  8   NO2-N       3285 non-null   object
#  9   NO3-N       3285 non-null   object
#  10  P-TOT       3285 non-null   object
#  11  P-SOL       3285 non-null   object
#  12  Cl          3285 non-null   object
#  13  F           3285 non-null   object
#  14  FOG         3285 non-null   object
#  15  Phenol-Man  3285 non-null   object
#  16  SO4         3285 non-null   object
#  17  CN (COMP)   3285 non-null   object
# ...

# %%
plantA_data.columns
# Out:
# Index(['Date', 'FLOW MGD', 'pH', 'BOD5', 'TS', 'SS', 'TKN', 'NH3-N', 'NO2-N',
#        'NO3-N', 'P-TOT', 'P-SOL', 'Cl', 'F', 'FOG', 'Phenol-Man', 'SO4',
#        'CN (COMP)', 'CN (GRAB)', 'CN_WAD', 'As', 'Ba', 'Cd', 'Cr', 'Cu', 'Fe',
#        'Fe(SOL)', 'Pb', 'Mn', 'Hg', 'Ni', 'Se', 'Ag', 'Zn', 'Sb', 'Be', 'Tl',
#        'Cr6', 'As Sol', 'Ba Sol', 'Cd Sol', 'Cr Sol', 'Cu Sol', 'Pb Sol',
#        'Mn Sol', 'Hg Sol', 'Ni Sol', 'Se Sol', 'Ag Sol', 'Zn Sol', 'Sb Sol',
#        'Be Sol', 'Tl Sol'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
import re

data_columns = plantA_data.columns.tolist()
columns = data_columns[1:]
columns

for col in columns:
    for row in range(len(plantA_data[col])):
        element = plantA_data[col].iloc[row]
        if type(element) == str:
            if '<' in element:
                smaller = element.index('<') + 1
                mo = re.match('.+([0-9])[^0-9]*$', element)
                last_digit = mo.start(1) + 1
                plantA_data.at[row, col] = float(element[smaller:last_digit]) - float(element[smaller:last_digit]) * 0.01
            
plantA_data
# Out:
#            Date  FLOW MGD   pH BOD5    TS   SS    TKN  NH3-N   NO2-N    NO3-N  \
# 0    2002-01-01     23.42  7.4  118   761  108   27.7  14.57    0.01   0.0297
# 1    2002-01-02     25.13  7.5  151   776  138   41.5  16.38    0.02   0.0297
# 2    2002-01-03     25.65  7.1  297  1064  354   41.7  17.61    0.03   0.0297
# 3    2002-01-04     26.32  7.1  230   921  176   35.1  15.93  0.0099     0.04
# 4    2002-01-05     23.94  7.0  204   895  154   33.7  16.14  0.0099     0.04
# ...         ...       ...  ...  ...   ...  ...    ...    ...     ...      ...
# 3280 2010-12-27     22.58  7.5  145  1094   96  32.63  23.04    0.14  0.13365
# 3281 2010-12-28     22.68  7.4  262  1163  326  36.82   23.0   0.081  0.13365
# 3282 2010-12-29     22.28  7.4  171  1008  182  31.32  21.51   0.039  0.13365
# 3283 2010-12-30     32.18  7.4  172  1317  226  26.98   16.3   0.091  0.13365
# 3284 2010-12-31     84.55  7.3   60  1236  126  14.41   6.66   0.554    1.158
#
# ...

# %%
plantA_data = plantA_data._convert(numeric=True)

# %%
plantA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3285 entries, 0 to 3284
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        3285 non-null   datetime64[ns]
#  1   FLOW MGD    3285 non-null   float64
#  2   pH          3284 non-null   float64
#  3   BOD5        3248 non-null   float64
#  4   TS          3283 non-null   float64
#  5   SS          3282 non-null   float64
#  6   TKN         3283 non-null   float64
#  7   NH3-N       3283 non-null   float64
#  8   NO2-N       3283 non-null   float64
#  9   NO3-N       3282 non-null   float64
#  10  P-TOT       3283 non-null   float64
#  11  P-SOL       474 non-null    float64
#  12  Cl          470 non-null    float64
#  13  F           469 non-null    float64
#  14  FOG         468 non-null    float64
#  15  Phenol-Man  467 non-null    float64
#  16  SO4         470 non-null    float64
#  17  CN (COMP)   2346 non-null   float64
# ...

# %%
plantA_data.describe()
# Out:
#           FLOW MGD           pH         BOD5           TS           SS  \
# count  3285.000000  3284.000000  3248.000000  3283.000000  3282.000000
# mean     35.882478     7.305664   165.488300   958.640573   186.992078
# std      20.544946     0.190511    78.895895   221.032459   128.517078
# min      13.900000     6.400000    21.000000   306.000000    15.000000
# 25%      24.260000     7.200000   126.750000   845.500000   128.000000
# 50%      28.860000     7.300000   161.000000   932.000000   174.000000
# 75%      38.020000     7.400000   198.250000  1039.000000   216.000000
# max     147.540000     8.600000  2663.000000  3759.000000  3170.000000
#
#                TKN        NH3-N        NO2-N        NO3-N        P-TOT  ...  \
# count  3283.000000  3283.000000  3283.000000  3282.000000  3283.000000  ...
# mean     26.092342    14.867335     0.173609     0.231393     4.328894  ...
# std       7.800527     4.812499     0.262259     0.517386     1.579018  ...
# ...

# %% [markdown]
# ## Plot to See the Data Structure Before Filling NAs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pylab as pl
plantA_data.hist(bins=50, figsize=(100,100))
pl.suptitle("A histogram for each numerical attribute")
plt.show()

# %% [markdown]
# ## Filling NAs

# %%
nans_indices = plantA_data.columns[plantA_data.isnull().any()].tolist()
nans_indices
# Out:
# ['pH',
#  'BOD5',
#  'TS',
#  'SS',
#  'TKN',
#  'NH3-N',
#  'NO2-N',
#  'NO3-N',
#  'P-TOT',
#  'P-SOL',
#  'Cl',
#  'F',
#  'FOG',
#  'Phenol-Man',
#  'SO4',
#  'CN (COMP)',
#  'CN (GRAB)',
#  'CN_WAD',
#  'As',
#  'Ba',
#  'Cd',
#  'Cr',
#  'Cu',
#  'Fe',
#  'Fe(SOL)',
#  'Pb',
#  'Mn',
#  'Hg',
#  'Ni',
#  'Se',
#  'Ag',
#  'Zn',
#  'Sb',
#  'Be',
#  'Tl',
#  'Cr6',
#  'As Sol',
#  'Ba Sol',
#  'Cd Sol',
#  'Cr Sol',
#  'Cu Sol',
#  'Pb Sol',
#  'Mn Sol',
#  'Hg Sol',
#  'Ni Sol',
#  'Se Sol',
#  'Ag Sol',
#  'Zn Sol',
#  'Sb Sol',
#  'Be Sol',
#  'Tl Sol']

# %%
for indice in nans_indices:
    plantA_data[indice].fillna(method = 'pad', inplace=True) 
    # pad / ffill: propagate last valid observation forward to next valid

# %%
plantA_data
# Out:
#            Date  FLOW MGD   pH   BOD5      TS     SS    TKN  NH3-N   NO2-N  \
# 0    2002-01-01     23.42  7.4  118.0   761.0  108.0  27.70  14.57  0.0100
# 1    2002-01-02     25.13  7.5  151.0   776.0  138.0  41.50  16.38  0.0200
# 2    2002-01-03     25.65  7.1  297.0  1064.0  354.0  41.70  17.61  0.0300
# 3    2002-01-04     26.32  7.1  230.0   921.0  176.0  35.10  15.93  0.0099
# 4    2002-01-05     23.94  7.0  204.0   895.0  154.0  33.70  16.14  0.0099
# ...         ...       ...  ...    ...     ...    ...    ...    ...     ...
# 3280 2010-12-27     22.58  7.5  145.0  1094.0   96.0  32.63  23.04  0.1400
# 3281 2010-12-28     22.68  7.4  262.0  1163.0  326.0  36.82  23.00  0.0810
# 3282 2010-12-29     22.28  7.4  171.0  1008.0  182.0  31.32  21.51  0.0390
# 3283 2010-12-30     32.18  7.4  172.0  1317.0  226.0  26.98  16.30  0.0910
# 3284 2010-12-31     84.55  7.3   60.0  1236.0  126.0  14.41   6.66  0.5540
#
# ...

# %%
nan_indices = plantA_data.columns[plantA_data.isnull().any()].tolist()
nan_indices
# Out:
# ['FOG', 'Phenol-Man', 'SO4', 'Cr6']

# %%
for nan_col in nan_indices:
    plantA_data[nan_col].fillna(method = 'bfill', inplace=True)
    # backfill / bfill: use next valid observation to fill gap

# %%
na_indices = plantA_data.columns[plantA_data.isnull().any()].tolist()
na_indices
# Out:
# []

# %%
plantA_data
# Out:
#            Date  FLOW MGD   pH   BOD5      TS     SS    TKN  NH3-N   NO2-N  \
# 0    2002-01-01     23.42  7.4  118.0   761.0  108.0  27.70  14.57  0.0100
# 1    2002-01-02     25.13  7.5  151.0   776.0  138.0  41.50  16.38  0.0200
# 2    2002-01-03     25.65  7.1  297.0  1064.0  354.0  41.70  17.61  0.0300
# 3    2002-01-04     26.32  7.1  230.0   921.0  176.0  35.10  15.93  0.0099
# 4    2002-01-05     23.94  7.0  204.0   895.0  154.0  33.70  16.14  0.0099
# ...         ...       ...  ...    ...     ...    ...    ...    ...     ...
# 3280 2010-12-27     22.58  7.5  145.0  1094.0   96.0  32.63  23.04  0.1400
# 3281 2010-12-28     22.68  7.4  262.0  1163.0  326.0  36.82  23.00  0.0810
# 3282 2010-12-29     22.28  7.4  171.0  1008.0  182.0  31.32  21.51  0.0390
# 3283 2010-12-30     32.18  7.4  172.0  1317.0  226.0  26.98  16.30  0.0910
# 3284 2010-12-31     84.55  7.3   60.0  1236.0  126.0  14.41   6.66  0.5540
#
# ...

# %%
plantA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3285 entries, 0 to 3284
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        3285 non-null   datetime64[ns]
#  1   FLOW MGD    3285 non-null   float64
#  2   pH          3285 non-null   float64
#  3   BOD5        3285 non-null   float64
#  4   TS          3285 non-null   float64
#  5   SS          3285 non-null   float64
#  6   TKN         3285 non-null   float64
#  7   NH3-N       3285 non-null   float64
#  8   NO2-N       3285 non-null   float64
#  9   NO3-N       3285 non-null   float64
#  10  P-TOT       3285 non-null   float64
#  11  P-SOL       3285 non-null   float64
#  12  Cl          3285 non-null   float64
#  13  F           3285 non-null   float64
#  14  FOG         3285 non-null   float64
#  15  Phenol-Man  3285 non-null   float64
#  16  SO4         3285 non-null   float64
#  17  CN (COMP)   3285 non-null   float64
# ...

# %%
plantA_data.describe() # examine again
# Out:
#           FLOW MGD           pH         BOD5           TS           SS  \
# count  3285.000000  3285.000000  3285.000000  3285.000000  3285.000000
# mean     35.882478     7.305662   164.607306   958.504718   186.911720
# std      20.544946     0.190482    79.525093   221.050834   128.498807
# min      13.900000     6.400000    21.000000   306.000000    15.000000
# 25%      24.260000     7.200000   126.000000   845.000000   128.000000
# 50%      28.860000     7.300000   160.000000   932.000000   174.000000
# 75%      38.020000     7.400000   198.000000  1039.000000   216.000000
# max     147.540000     8.600000  2663.000000  3759.000000  3170.000000
#
#                TKN        NH3-N        NO2-N        NO3-N        P-TOT  ...  \
# count  3285.000000  3285.000000  3285.000000  3285.000000  3285.000000  ...
# mean     26.086746    14.863461     0.173613     0.232107     4.327890  ...
# std       7.805669     4.816187     0.262199     0.519393     1.579567  ...
# ...

# %%
# plot again to see data structures after filling NAs
# %matplotlib inline 
import matplotlib.pyplot as plt
import pylab as pl
plantA_data.hist(bins=50, figsize=(100,100))
pl.suptitle("A histogram for each numerical attribute")
plt.show()

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(plantA_data, test_size=0.2, random_state=42)

# %%
test_set.head()
# Out:
#            Date  FLOW MGD   pH   BOD5      TS     SS    TKN  NH3-N  NO2-N  \
# 2209 2008-01-20     36.83  7.5  383.0  1346.0  521.0  40.28  19.46  0.123
# 2770 2009-08-04     29.43  7.4  170.0   872.0  168.0  34.78  23.72  0.583
# 1656 2006-07-16     23.87  7.2  177.0   916.0  192.0  27.00  17.23  0.051
# 1652 2006-07-12     27.47  7.2  176.0   848.0  171.0  26.90  17.09  0.054
# 1451 2005-12-23     23.27  7.2  260.0  1021.0  329.0  36.10  20.15  0.050
#
#        NO3-N  ...   Pb Sol  Mn Sol  Hg Sol  Ni Sol   Se Sol    Ag Sol  Zn Sol  \
# 2209  0.0300  ...  0.00198  0.0515  0.0600  0.0023  0.00396  0.000297  0.0194
# 2770  0.1200  ...  0.00198  0.0556  0.0198  0.0067  0.00396  0.000297  0.0169
# 1656  0.0198  ...  0.00198  0.0516  0.0495  0.0030  0.00396  0.000297  0.0200
# 1652  0.0198  ...  0.00198  0.0516  0.0495  0.0030  0.00396  0.000297  0.0200
# 1451  0.0198  ...  0.00300  0.0567  0.0495  0.0090  0.00396  0.000297  0.0290
#
#        Sb Sol    Be Sol  Tl Sol
# ...

# %%
plantA_data["P-TOT"].hist()  # x axis P-TOT value, y axis distibution of value
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Looking for Correlations

# %%
corr_matrix = plantA_data.corr()

# %%
corr_matrix["P-TOT"].sort_values(ascending=False)
# Out:
# P-TOT         1.000000
# TKN           0.910908
# BOD5          0.813209
# Cu            0.752283
# SS            0.737130
# NH3-N         0.676733
# Zn            0.631233
# Mn            0.595217
# Ba            0.580666
# Fe            0.513679
# Ag            0.505839
# Cr            0.437040
# P-SOL         0.403728
# TS            0.388084
# Pb            0.302541
# Ni            0.265835
# Phenol-Man    0.216279
# Fe(SOL)       0.203653
# CN (GRAB)     0.178083
# Mn Sol        0.125075
# Ni Sol        0.095021
# Cd            0.088226
# CN_WAD        0.087603
# Hg Sol        0.085800
# Hg            0.068228
# FOG           0.060278
# Ag Sol        0.056547
# CN (COMP)     0.048773
# Se Sol        0.047571
# SO4           0.043134
# Cu Sol        0.037380
# Zn Sol        0.036986
# Be Sol        0.014140
# Se            0.009864
# Sb Sol        0.008402
# Tl            0.005223
# Cr Sol        0.004757
# Be            0.003242
# Cr6           0.002782
# Sb            0.001121
# ...

# %%
from pandas.plotting import scatter_matrix

attributes = ["P-TOT", "TKN", "BOD5", "Cu", "SS", "NH3-N", "Zn", "Mn", "Ba", "Fe", "Ag", "Cr", "P-SOL"]
scatter_matrix(plantA_data[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='P-TOT', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='TKN', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='BOD5', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='Cu', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='SS', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='NH3-N', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='Zn', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='Mn', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='Ba', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='Fe', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='Ag', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='Cr', ylabel='P-TOT'>,
#         <AxesSubplot:xlabel='P-SOL', ylabel='P-TOT'>],
#        [<AxesSubplot:xlabel='P-TOT', ylabel='TKN'>,
#         <AxesSubplot:xlabel='TKN', ylabel='TKN'>,
#         <AxesSubplot:xlabel='BOD5', ylabel='TKN'>,
#         <AxesSubplot:xlabel='Cu', ylabel='TKN'>,
#         <AxesSubplot:xlabel='SS', ylabel='TKN'>,
# ...

# %%
plantA_data.plot(kind="scatter", x="TKN", y="P-TOT", alpha=0.1) 
# Matplotlib allows you to adjust the transparency of a graph plot using the alpha attribute. By default, alpha=1
# If you want to make the graph plot more transparent, then you can make alpha less than 1, such as 0.5 or 0.25.
# If you want to make the graph plot less transparent, then you can make alpha greater than 1.
# Out:
# <AxesSubplot:xlabel='TKN', ylabel='P-TOT'>

# %%
plantA_data.plot(kind="scatter", x="BOD5", y="P-TOT")
# Out:
# <AxesSubplot:xlabel='BOD5', ylabel='P-TOT'>

# %% [markdown]
# # Prepare the Data for Machine Learning Algorithms

# %%
from sklearn.model_selection import train_test_split

Data_train, Data_test, ptot_train, ptot_test = train_test_split(plantA_data, plantA_data["P-TOT"], random_state=42)

# %%
data_train = Data_train.drop("P-TOT", axis=1) # drop labels for training set
data_train_labels = Data_train["P-TOT"].copy()

# %%
data_train = data_train.drop(columns="Date")

# %%
data_train.median()
# Out:
# FLOW MGD       28.950000
# pH              7.300000
# BOD5          160.000000
# TS            930.000000
# SS            174.000000
# TKN            27.400000
# NH3-N          15.490000
# NO2-N           0.051000
# NO3-N           0.029700
# P-SOL           1.820000
# Cl            166.300000
# F               1.230000
# FOG            16.600000
# Phenol-Man     29.100000
# SO4            77.800000
# CN (COMP)       0.012000
# CN (GRAB)       0.010000
# CN_WAD          0.001200
# As              0.013000
# Ba              0.058400
# Cd              0.000594
# Cr              0.011000
# Cu              0.080000
# Fe              1.280000
# Fe(SOL)         0.151000
# Pb              0.006000
# Mn              0.076700
# Hg              0.070000
# Ni              0.011300
# Se              0.002970
# Ag              0.004000
# Zn              0.139500
# Sb              0.008910
# Be              0.000198
# Tl              0.029700
# Cr6             1.980000
# As Sol          0.014000
# ...

# %% [markdown]
# ## Transformation Pipelines

# %% [markdown]
# There are two common ways to get all attributes to have the same scale: min-max scaling and standardization.
#
# Min-max scaling (many people call this normalization) is the simplest: values are shifted and rescaled so that they end up ranging from 0 to 1. We do this by subtracting the min value and dividing by the max minus the min. Scikit-Learn provides a transformer called MinMaxScaler for this. It has a feature_range hyperparameter that lets you change the range if, for some reason, you don’t want 0–1.
#
# Standardization is different: first it subtracts the mean value (so standardized values always have a zero mean), and then it divides by the standard deviation so that the resulting distribution has unit variance. Unlike min-max scaling, standardization
# does not bound values to a specific range, which may be a problem for some algorithms (e.g., neural networks often expect an input value ranging from 0 to 1). However, standardization is much less affected by outliers.

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        # ('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
    ])

data_train_tr = num_pipeline.fit_transform(data_train)

# %% [markdown]
# When the pipeline’s fit() method is called, it calls fit_transform() sequentially on all transformers, passing the output of each call as the parameter to the next call until it reaches the final estimator, for which it calls the fit() method.

# %%
data_train_tr
# Out:
# array([[-0.18814891,  1.52798766,  0.54082515, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.03616609, -1.62616817,  1.16992922, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.45595144, -0.04909026,  0.46533267, ...,  3.1518427 ,
#          3.2926025 ,  1.68905131],
#        ...,
#        [-0.55759912, -0.04909026,  1.47189916, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.01564108,  1.00229502,  0.79246678, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.29566088,  1.00229502, -0.59156215, ...,  3.1518427 ,
#          3.2926025 ,  1.68905131]])

# %% [markdown]
# Instead of handling the categorical columns and the numerical columns separately. It would be more convenient to have a single transformer able to handle all columns, applying the appropriate transformations to each column. In version 0.20, Scikit-Learn introduced the ColumnTransformer for this purpose, and it works great with pandas DataFrames.

# %%
from sklearn.compose import ColumnTransformer

num_attribs = list(data_train)

full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
    ])

data_train_prepared = full_pipeline.fit_transform(data_train)

# %%
data_train_prepared
# Out:
# array([[-0.18814891,  1.52798766,  0.54082515, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.03616609, -1.62616817,  1.16992922, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.45595144, -0.04909026,  0.46533267, ...,  3.1518427 ,
#          3.2926025 ,  1.68905131],
#        ...,
#        [-0.55759912, -0.04909026,  1.47189916, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.01564108,  1.00229502,  0.79246678, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.29566088,  1.00229502, -0.59156215, ...,  3.1518427 ,
#          3.2926025 ,  1.68905131]])

# %%
data_train_prepared.shape
# Out:
# (2463, 51)

# %% [markdown]
# Here is the old solution based on a DataFrameSelector transformer (to just select a subset of the Pandas DataFrame columns), and a FeatureUnion :

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# Create a class to select numerical or categorical columns 
class OldDataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
num_attribs = list(data_train)

old_num_pipeline = Pipeline([
        ('selector', OldDataFrameSelector(num_attribs)),
        ('imputer', SimpleImputer(strategy="median")),
        ('std_scaler', StandardScaler()),
    ])

# %%
from sklearn.pipeline import FeatureUnion

old_full_pipeline = FeatureUnion(transformer_list=[
        ("num_pipeline", old_num_pipeline),
    ])

# %%
old_data_train_prepared = old_full_pipeline.fit_transform(data_train)
old_data_train_prepared
# Out:
# array([[-0.18814891,  1.52798766,  0.54082515, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.03616609, -1.62616817,  1.16992922, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.45595144, -0.04909026,  0.46533267, ...,  3.1518427 ,
#          3.2926025 ,  1.68905131],
#        ...,
#        [-0.55759912, -0.04909026,  1.47189916, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.01564108,  1.00229502,  0.79246678, ..., -0.34226817,
#         -0.32828231, -0.30702235],
#        [-0.29566088,  1.00229502, -0.59156215, ...,  3.1518427 ,
#          3.2926025 ,  1.68905131]])

# %% [markdown]
# The result is the same as with the ColumnTransformer :

# %%
np.allclose(data_train_prepared, old_data_train_prepared)
# Out:
# True

# %% [markdown]
# # Select and Train a Model
# ## Training and Evaluating on the Training Set

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(data_train_prepared, data_train_labels)
# Out:
# LinearRegression()

# %%
# let's try the full preprocessing pipeline on a few training instances
some_data = data_train.iloc[:5]
some_labels = data_train_labels.iloc[:5]
some_data_prepared = full_pipeline.transform(some_data)

print("Predictions:", lin_reg.predict(some_data_prepared))
# Out:
# Predictions: [5.40837545 5.54051226 5.56771776 4.20291529 3.76918336]

# %% [markdown]
#   Compare against the actual values:

# %%
print("Labels:", list(some_labels))
# Out:
# Labels: [5.75, 5.55, 5.63, 4.13, 4.05]

# %%
some_data_prepared
# Out:
# array([[-0.18814891,  1.52798766,  0.54082515,  0.15236675,  0.76553801,
#          0.60908676,  1.03158392, -0.42144694, -0.40875498,  0.37029663,
#          0.17801026, -0.58152757,  0.70929557,  0.09238315,  0.92046294,
#         -0.69131151,  0.12412118, -0.56867984,  1.23288742,  0.27637183,
#         -0.21289196, -0.37397697,  0.54663022,  0.22577428, -0.17732234,
#         -0.47830748,  0.28998855,  0.44840358,  0.06486106, -0.42381247,
#          0.27442312,  0.62215897, -0.34872793, -0.35042289, -0.33865202,
#         -0.3453807 ,  0.93912187, -0.29811128, -0.3013471 , -0.3455377 ,
#         -0.59009209, -0.51816356,  0.41392843, -0.93956065, -0.35285698,
#         -0.49772526, -0.43080411, -0.46525413, -0.34226817, -0.32828231,
#         -0.30702235],
#        [-0.03616609, -1.62616817,  1.16992922, -0.18589155,  0.76553801,
#          0.57821162,  0.11520499, -0.39799384, -0.40875498,  0.1310784 ,
#          0.36518913, -0.57912286,  0.87914328,  2.13801477,  0.2460006 ,
# ...

# %% [markdown]
# Measure this regression model’s RMSE on the whole training set using Scikit-Learn’s mean_squared_error() function:

# %%
from sklearn.metrics import mean_squared_error 

data_train_predictions = lin_reg.predict(data_train_prepared)
lin_mse = mean_squared_error(data_train_labels, data_train_predictions)  # 均方误差
lin_rmse = np.sqrt(lin_mse)
lin_rmse  # P-TOT ranges between 0.53 and 34.80 with a mean of 4.328, so a typical prediction error of 0.476 is OK.
# Out:
# 0.476041262175769

# %%
from sklearn.metrics import mean_absolute_error

lin_mae = mean_absolute_error(data_train_labels, data_train_predictions)  # 平均绝对误差 
lin_mae
# Out:
# 0.27892842892940245

# %% [markdown]
# DecisionTreeRegressor is a powerful model, capable of finding complex nonlinear relationships in the data.

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(data_train_prepared, data_train_labels)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
data_train_predictions = tree_reg.predict(data_train_prepared)
tree_mse = mean_squared_error(data_train_labels, data_train_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 1.549882028850149e-17

# %% [markdown]
# # Better Evaluation Using Cross-Validation

# %% [markdown]
# One way to evaluate the Decision Tree model would be to use the train_test_split() function to split the training set into a smaller training set and a validation set, then train your models against the smaller training set and evaluate them against the validation set. It’s a bit of work, but nothing too difficult, and it would work fairly well.
#
# A great alternative is to use Scikit-Learn’s K-fold cross-validation feature. The following code randomly splits the training set into 10 distinct subsets called folds, then it trains and evaluates the Decision Tree model 10 times, picking a different fold for evaluation every time and training on the other 9 folds. The result is an array containing the 10 evaluation scores:

# %% [markdown]
# Scikit-Learn’s cross-validation features expect a utility function (greater is better) rather than a cost function (lower is better), so the scoring function is actually the opposite of the MSE (i.e., a negative value), which is why the preceding code computes -scores before calculating the square root.

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_reg, data_train_prepared, data_train_labels, scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [1.07450224 0.51444518 0.68400967 1.15960009 1.55651947 0.63122928
#  0.49855768 0.57641237 0.85017191 0.5143644 ]
# Mean: 0.8059812276356293
# Standard deviation: 0.33542068185152113

# %% [markdown]
# Now the Decision Tree doesn’t look as good as it did earlier. In fact, it seems to perform worse than the Linear Regression model! Notice that cross-validation allows us to get not only an estimate of the performance of our model, but also a measure
# of how precise this estimate is (i.e., its standard deviation). The Decision Tree has a score of approximately 0.80598, generally ±0.33542. We would not have this information if we just used one validation set. But cross-validation comes at the cost of training the model several times, so it is not always possible.

# %% [markdown]
# Let’s compute the same scores for the Linear Regression model just to be sure:

# %%
lin_scores = cross_val_score(lin_reg, data_train_prepared, data_train_labels, scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [0.97649583 0.38500623 0.42048474 0.4617632  0.39322062 0.4631273
#  0.40580261 0.34059588 0.36476642 0.33709941]
# Mean: 0.45483622410093716
# Standard deviation: 0.1787534280615653

# %% [markdown]
# That’s right: the Decision Tree model is overfitting so badly that it performs worse than the Linear Regression model.

# %% [markdown]
# Let’s try another model now: the RandomForestRegressor. Random Forests work by training many Decision Trees on random subsets of the features, then averaging out their predictions. Building a model on top of many other models is called Ensemble Learning, and it is often a great way to push ML algorithms even further.

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=100, random_state=42)
forest_reg.fit(data_train_prepared, data_train_labels)
# Out:
# RandomForestRegressor(random_state=42)

# %%
data_train_predictions = forest_reg.predict(data_train_prepared)
forest_mse = mean_squared_error(data_train_labels, data_train_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 0.2667407973824506

# %%
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, data_train_prepared, data_train_labels,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [1.01065362 0.39063429 0.42801623 0.53628058 1.54273658 0.47198428
#  0.37797944 0.42519539 0.38689957 0.37721288]
# Mean: 0.5947592856363948
# Standard deviation: 0.3641250163836343

# %% [markdown]
# In our case, the performance of Random Forests is still not as good as the Linear Regression model.

# %%
scores = cross_val_score(lin_reg, data_train_prepared, data_train_labels, scoring="neg_mean_squared_error", cv=10)
pd.Series(np.sqrt(-scores)).describe()
# Out:
# count    10.000000
# mean      0.454836
# std       0.188423
# min       0.337099
# 25%       0.369826
# 50%       0.399512
# 75%       0.451444
# max       0.976496
# dtype: float64

# %%
from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")  # Support Vector Regression
svm_reg.fit(data_train_prepared, data_train_labels)
data_train_predictions = svm_reg.predict(data_train_prepared)
svm_mse = mean_squared_error(data_train_labels, data_train_predictions)
svm_rmse = np.sqrt(svm_mse)
svm_rmse
# Out:
# 0.48693756133409133

# %% [markdown]
# # Fine-Tune the Model
# ## Grid Search

# %% [markdown]
# GridSearch can be used to search for a great combination of hyperparameter values. All you need to do is tell it which hyperparameters you want it to experiment with and what values to try out, and it will use cross-validation to evaluate all the possible combinations of hyperparameter values. For example, the following code searches for the best combination of hyperparameter values for the RandomForestRegressor:

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap set as False
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)
grid_search.fit(data_train_prepared, data_train_labels)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %% [markdown]
# The best hyperparameter combination found:

# %%
grid_search.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=8, n_estimators=30, random_state=42)

# %% [markdown]
# If GridSearchCV is initialized with refit=True (which is the default), then once it finds the best estimator using cross-validation, it retrains it on the whole training set. This is usually a good idea, since feeding it more data will likely improve its performance.

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)  # evaluation score
# Out:
# 0.9671889283796461 {'max_features': 2, 'n_estimators': 3}
# 0.8742619126588942 {'max_features': 2, 'n_estimators': 10}
# 0.8276770105175062 {'max_features': 2, 'n_estimators': 30}
# 0.9321254113070997 {'max_features': 4, 'n_estimators': 3}
# 0.832570538552992 {'max_features': 4, 'n_estimators': 10}
# 0.7804662200423951 {'max_features': 4, 'n_estimators': 30}
# 0.8703257594299899 {'max_features': 6, 'n_estimators': 3}
# 0.7977697556934334 {'max_features': 6, 'n_estimators': 10}
# 0.764320314432955 {'max_features': 6, 'n_estimators': 30}
# 0.8942061267844977 {'max_features': 8, 'n_estimators': 3}
# 0.7814254636786399 {'max_features': 8, 'n_estimators': 10}
# 0.7521051992656828 {'max_features': 8, 'n_estimators': 30}
# 0.9554471335376894 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 0.8719639755852392 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 0.915651502970442 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# ...

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011003      0.001547         0.001602        0.000491
# 1        0.029410      0.001856         0.002001        0.000004
# 2        0.088021      0.003397         0.005002        0.000003
# 3        0.012806      0.000751         0.000999        0.000002
# 4        0.040804      0.001935         0.002005        0.000004
# 5        0.126827      0.005041         0.005002        0.000006
# 6        0.017599      0.000496         0.001203        0.000402
# 7        0.053219      0.001168         0.001998        0.000008
# 8        0.157237      0.003375         0.004802        0.000400
# 9        0.020002      0.000892         0.001202        0.000400
# 10       0.063717      0.001764         0.002202        0.000403
# 11       0.187647      0.004176         0.004402        0.000491
# 12       0.013001      0.000009         0.000997        0.000005
# ...

# %% [markdown]
# ## Randomized Search

# %% [markdown]
# The grid search approach is fine when you are exploring relatively few combinations, like in the previous example, but when the hyperparameter search space is large, it is often preferable to use RandomizedSearchCV instead. This class can be used in much
# the same way as the GridSearchCV class, but instead of trying out all possible combinations, it evaluates a given number of random combinations by selecting a random value for each hyperparameter at every iteration. This approach has two main benefits:
# - If you let the randomized search run for, say, 1,000 iterations, this approach will explore 1,000 different values for each hyperparameter (instead of just a few values per hyperparameter with the grid search approach).
# - Simply by setting the number of iterations, you have more control over the computing budget you want to allocate to hyperparameter search.

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=100),
        'max_features': randint(low=1, high=51),
    }

forest_reg = RandomForestRegressor(random_state=42)
rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42)
rnd_search.fit(data_train_prepared, data_train_labels)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    param_distributions={'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001C6B5BE0490>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001C6B5BDA2B0>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 0.6958725230278532 {'max_features': 39, 'n_estimators': 52}
# 0.7119073950877941 {'max_features': 29, 'n_estimators': 15}
# 0.7033384110688067 {'max_features': 43, 'n_estimators': 72}
# 0.7053720082014387 {'max_features': 21, 'n_estimators': 83}
# 0.6933093401807011 {'max_features': 23, 'n_estimators': 75}
# 0.7192348020086359 {'max_features': 11, 'n_estimators': 88}
# 0.7048198361609871 {'max_features': 36, 'n_estimators': 24}
# 0.821929426774547 {'max_features': 3, 'n_estimators': 22}
# 0.8196260478004379 {'max_features': 2, 'n_estimators': 88}
# 0.7108121762355047 {'max_features': 44, 'n_estimators': 30}

# %% [markdown]
# ## Analyze the Best Models and Their Errors

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([1.85393266e-02, 1.86676289e-03, 9.38339815e-02, 2.71879212e-02,
#        5.78698191e-02, 2.09042469e-01, 9.54438698e-02, 2.48999444e-02,
#        2.62323557e-02, 2.27419867e-02, 2.28826968e-03, 7.32027540e-03,
#        5.82687115e-03, 2.76481216e-03, 4.50197481e-03, 5.18524845e-03,
#        2.49663094e-03, 2.44252733e-03, 1.71745199e-03, 3.06204849e-02,
#        1.75636482e-03, 2.24628596e-02, 1.10167444e-01, 3.14278316e-02,
#        3.67868117e-03, 6.73794289e-03, 7.20281477e-02, 3.22016570e-03,
#        1.03187783e-02, 8.19258656e-04, 8.09616751e-03, 5.57206152e-02,
#        1.55143775e-04, 9.86777951e-05, 4.79130960e-05, 4.61844120e-04,
#        2.04565587e-03, 5.70360927e-03, 9.66563551e-04, 8.41376101e-04,
#        2.14321525e-03, 4.64549165e-03, 3.70682915e-03, 3.23818869e-03,
#        1.96809172e-03, 4.09738200e-04, 7.45899273e-04, 3.21048610e-03,
#        1.30509152e-04, 9.14049268e-05, 1.32121378e-04])

# %% [markdown]
# ## Evaluate Our System on the Test Set

# %%
final_model = grid_search.best_estimator_

X_test = Data_test.drop("P-TOT", axis=1)
y_test = Data_test["P-TOT"].copy()

X_test = X_test.drop(columns="Date")
X_test_prepared = full_pipeline.transform(X_test)
final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse
# Out:
# 0.5196636734162828

# %% [markdown]
# In some cases, such a point estimate of the generalization error will not be quite enough to convince us to launch: what if it is just 0.1% better than the model currently in production? We might want to have an idea of how precise this estimate is. For this, We can compute a 95% confidence interval for the generalization error using scipy.stats.t.interval():

# %%
from scipy import stats

confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors) - 1,
                         loc=squared_errors.mean(),
                         scale=stats.sem(squared_errors)))
# Out:
# array([0.39290868, 0.62106637])

# %% [markdown]
# We could compute the interval manually like this:

# %%
m = len(squared_errors)
mean = squared_errors.mean()
tscore = stats.t.ppf((1 + confidence) / 2, df=m - 1)
tmargin = tscore * squared_errors.std(ddof=1) / np.sqrt(m)
np.sqrt(mean - tmargin), np.sqrt(mean + tmargin)
# Out:
# (0.3929086788935811, 0.6210663708389874)

# %% [markdown]
# Alternatively, we could use a z-scores rather than t-scores:

# %%
zscore = stats.norm.ppf((1 + confidence) / 2)
zmargin = zscore * squared_errors.std(ddof=1) / np.sqrt(m)
np.sqrt(mean - zmargin), np.sqrt(mean + zmargin)
# Out:
# (0.39312562550881097, 0.620929069624958)

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# A linear model can be used to fit nonlinear data. A simple way to do this is to add powers of each feature as new features, then train a linear model on this extended set of features. This technique is called Polynomial Regression.

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=False)  
# adding the square (second-degree polynomial) of each feature in the training set as a new feature
X_poly = poly_features.fit_transform(data_train)

# %%
X_poly[0]
# Out:
# array([3.2020e+01, 7.6000e+00, 2.0700e+02, ..., 3.9204e-08, 3.9204e-06,
#        3.9204e-04])

# %% [markdown]
# X_poly now contains the original feature of X plus the square of this feature. Now we can fit a LinearRegression model to this extended training data:

# %%
y = data_train_labels

lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (82885.67935888136,
#  array([-2.30212643e+01,  2.45945429e+03, -5.83076278e+00, ...,
#         -8.42629964e+01, -1.01607959e+03,  4.03676963e+04]))

# %% [markdown]
# # Regularized Linear Models
# ## Ridge Regression

# %%
X = data_train_prepared

from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=1, solver="cholesky", random_state=42)
ridge_reg.fit(X, y)
ridge_reg.predict(X)
# Out:
# array([5.39715269, 5.53537166, 5.55719593, ..., 6.61557936, 5.7302336 ,
#        4.24812683])

# %%
ridge_reg = Ridge(alpha=1, solver="sag", random_state=42)
ridge_reg.fit(X, y)
ridge_reg.predict(X)
# Out:
# array([5.4063067 , 5.53355412, 5.55670189, ..., 6.6445734 , 5.69423078,
#        4.24118255])

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3, penalty=None, eta0=0.1, random_state=42)
sgd_reg.fit(X, y.ravel())
# Out:
# SGDRegressor(eta0=0.1, penalty=None, random_state=42)

# %%
sgd_reg.intercept_, sgd_reg.coef_
# Out:
# (array([8.29763222]),
#  array([-3.00109825e+00,  3.67005689e+00,  6.46478337e+00, -2.79895971e+00,
#         -1.92426821e+01,  1.21537636e+01, -9.06269748e+00, -8.25964289e+00,
#          1.48414999e+00, -1.99250306e+01, -2.33981884e+01, -2.49821946e+00,
#          1.42936858e+01, -1.76060613e+00,  4.17632011e+01,  7.10181610e+01,
#         -9.83620597e+00, -3.41006284e+01, -9.06991741e+00,  2.42559044e+01,
#         -1.95424956e+00,  7.15069341e+00, -4.23385250e+00,  1.63754288e+01,
#          1.98565443e+00,  9.41114895e+00, -1.78789604e+01,  4.73951169e+00,
#          1.90669278e+01, -2.11748111e+01,  1.54228116e+00, -2.17763218e+01,
#          1.10363274e+04,  3.14441516e+02, -2.83087332e+03, -4.31053081e+01,
#          4.47066056e+01, -2.13150418e+01, -1.18200423e+01,  1.89821723e+01,
#         -1.30805594e+01, -6.48763107e+01, -1.70058221e+00, -1.71970003e+00,
#          1.69076954e+01, -1.38598934e+02,  5.74767951e+00,  2.25219591e+01,
# ...

# %%
sgd_reg = SGDRegressor(penalty="l2", max_iter=1000, tol=1e-3, random_state=42)
# The penalty hyperparameter sets the type of regularization term to use. Specifying "l2" indicates that you want SGD to add
# a regularization term to the cost function equal to half the square of the ℓ2 norm of the weight vector: this is simply 
# Ridge Regression.
sgd_reg.fit(X, y.ravel())
sgd_reg.predict(X)
# Out:
# array([5.43728876, 5.57711407, 5.52603164, ..., 6.9107876 , 5.74608688,
#        4.09116218])

# %% [markdown]
# ## Lasso Regression

# %% [markdown]
# Least Absolute Shrinkage and Selection Operator Regression (usually simply called Lasso Regression) is another regularized version of Linear Regression: just like Ridge Regression, it adds a regularization term to the cost function, but it uses the ℓ1 norm of the weight vector instead of half the square of the ℓ2 norm.

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(X, y)
lasso_reg.predict(X)
# Out:
# array([5.27074394, 5.34032654, 5.46975127, ..., 6.28051301, 5.22841241,
#        4.26054009])

# %% [markdown]
# ## Elastic Net

# %% [markdown]
# Elastic Net is a middle ground between Ridge Regression and Lasso Regression. The regularization term is a simple mix of both Ridge and Lasso’s regularization terms, and you can control the mix ratio r. When r = 0, Elastic Net is equivalent to Ridge
# Regression, and when r = 1, it is equivalent to Lasso Regression.

# %%
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
elastic_net.fit(X, y)
elastic_net.predict(X)
# Out:
# array([5.37147791, 5.36835586, 5.60705638, ..., 6.52663647, 5.10916425,
#        4.24779531])

# %% [markdown]
# # Regression MLP
# ## Use a regression neural network

# %%
data = plantA_data.drop(columns=["Date", "P-TOT"])
target = plantA_data["P-TOT"]

X_train_full, X_test, y_train_full, y_test = train_test_split(data, target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Using the Sequential API to build, train, evaluate, and use a regression MLP to make predictions is quite similar to classification. The main differences are the fact that the output layer has a single neuron (since we only want to predict a single value) and uses no activation function, and the loss function is the mean squared error.

# %%
from tensorflow import keras

model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1)
])
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(learning_rate=1e-3))
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
X_new = X_test[:3]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 1s 3ms/step - loss: 8.2531 - val_loss: 3.9429
# Epoch 2/20
# 58/58 [==============================] - 0s 1ms/step - loss: 3.2678 - val_loss: 2.1348
# Epoch 3/20
# 58/58 [==============================] - 0s 1ms/step - loss: 2.0923 - val_loss: 1.5454
# Epoch 4/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.5928 - val_loss: 1.2314
# Epoch 5/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.3291 - val_loss: 1.0546
# Epoch 6/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.1673 - val_loss: 0.9260
# Epoch 7/20
# 58/58 [==============================] - ETA: 0s - loss: 0.694 - 0s 1ms/step - loss: 1.0458 - val_loss: 0.8361
# Epoch 8/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.9504 - val_loss: 0.7675
# Epoch 9/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.8769 - val_loss: 0.7158
# Epoch 10/20
# ...

# %%
# plot neural network model performance over each training epoch

plt.plot(pd.DataFrame(history.history))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
y_pred
# Out:
# array([[7.1813736],
#        [5.446029 ],
#        [4.4514847]], dtype=float32)

# %% [markdown]
# # Functional API
# Not all neural network models are simply sequential. Some may have complex topologies. Some may have multiple inputs and/or multiple outputs. For example, a Wide & Deep neural network connects all or part of the inputs directly to the output layer.

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:])  
# Create an Input object.18 This is a specification of the kind of input the model will get, including its shape and dtype.
hidden1 = keras.layers.Dense(30, activation="relu")(input_)
# Create a Dense layer with 30 neurons, using the ReLU activation function. As soon as it is created, notice that we call 
# it like a function, passing it the input. This is why this is called the Functional API. 
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
# Create a second hidden layer, and again we use it as a function. We pass it the output of the first hidden layer.
concat = keras.layers.concatenate([input_, hidden2])
# Create a Concatenate layer, and once again we immediately use it like a function, to concatenate the input and the output 
# of the second hidden layer.
output = keras.layers.Dense(1)(concat)
# Create the output layer, with a single neuron and no activation function, and we call it like a function, passing it the 
# result of the concatenation.
model = keras.models.Model(inputs=[input_], outputs=[output])
# Create a Keras Model, specifying which inputs and outputs to use.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 51)]         0
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30)           1560        input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           930         dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 81)           0           input_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(learning_rate=1e-3))
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
y_pred = model.predict(X_new)
# Out:
# Epoch 1/20
# 58/58 [==============================] - 0s 2ms/step - loss: 10.1040 - val_loss: 3.1953
# Epoch 2/20
# 58/58 [==============================] - 0s 1ms/step - loss: 2.3896 - val_loss: 1.6398
# Epoch 3/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.5364 - val_loss: 1.2396
# Epoch 4/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.2086 - val_loss: 0.9721
# Epoch 5/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.0377 - val_loss: 0.8371
# Epoch 6/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.9376 - val_loss: 0.7467
# Epoch 7/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.8510 - val_loss: 0.6865
# Epoch 8/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.7894 - val_loss: 0.6339
# Epoch 9/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.7394 - val_loss: 0.6068
# Epoch 10/20
# ...

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
input_A = keras.layers.Input(shape=[5], name="wide_input")
input_B = keras.layers.Input(shape=[49], name="deep_input")
hidden1 = keras.layers.Dense(30, activation="relu")(input_B)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A, hidden2])
output = keras.layers.Dense(1, name="output")(concat)
model = keras.models.Model(inputs=[input_A, input_B], outputs=[output])

# %%
model.compile(loss="mse", optimizer=keras.optimizers.SGD(learning_rate=1e-3))

X_train_A, X_train_B = X_train[:, :5], X_train[:, 2:]
X_valid_A, X_valid_B = X_valid[:, :5], X_valid[:, 2:]
X_test_A, X_test_B = X_test[:, :5], X_test[:, 2:]
X_new_A, X_new_B = X_test_A[:3], X_test_B[:3]

history = model.fit((X_train_A, X_train_B), y_train, epochs=20,
                    validation_data=((X_valid_A, X_valid_B), y_valid))
mse_test = model.evaluate((X_test_A, X_test_B), y_test)
y_pred = model.predict((X_new_A, X_new_B))
# Out:
# Epoch 1/20
# 58/58 [==============================] - 0s 2ms/step - loss: 13.5424 - val_loss: 4.3400
# Epoch 2/20
# 58/58 [==============================] - 0s 1ms/step - loss: 3.4467 - val_loss: 2.2779
# Epoch 3/20
# 58/58 [==============================] - 0s 1ms/step - loss: 2.0293 - val_loss: 1.4694
# Epoch 4/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.4258 - val_loss: 1.1196
# Epoch 5/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.1472 - val_loss: 0.9592
# Epoch 6/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.0050 - val_loss: 0.8473
# Epoch 7/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.9094 - val_loss: 0.7791
# Epoch 8/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.8408 - val_loss: 0.7239
# Epoch 9/20
# 58/58 [==============================] - 0s 1ms/step - loss: 0.7843 - val_loss: 0.6783
# Epoch 10/20
# ...

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
input_A = keras.layers.Input(shape=[5], name="wide_input")
input_B = keras.layers.Input(shape=[49], name="deep_input")
hidden1 = keras.layers.Dense(30, activation="relu")(input_B)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A, hidden2])
output = keras.layers.Dense(1, name="main_output")(concat)
aux_output = keras.layers.Dense(1, name="aux_output")(hidden2)
model = keras.models.Model(inputs=[input_A, input_B],
                           outputs=[output, aux_output])

# %%
model.compile(loss=["mse", "mse"], loss_weights=[0.9, 0.1], optimizer=keras.optimizers.SGD(learning_rate=1e-3))

# %%
history = model.fit([X_train_A, X_train_B], [y_train, y_train], epochs=20,
                    validation_data=([X_valid_A, X_valid_B], [y_valid, y_valid]))
# Out:
# Epoch 1/20
# 58/58 [==============================] - 1s 4ms/step - loss: 14.7271 - main_output_loss: 14.3888 - aux_output_loss: 17.7715 - val_loss: 5.7369 - val_main_output_loss: 4.8333 - val_aux_output_loss: 13.8690
# Epoch 2/20
# 58/58 [==============================] - 0s 1ms/step - loss: 4.6184 - main_output_loss: 3.7368 - aux_output_loss: 12.5527 - val_loss: 3.1659 - val_main_output_loss: 2.4676 - val_aux_output_loss: 9.4506
# Epoch 3/20
# 58/58 [==============================] - 0s 1ms/step - loss: 2.8400 - main_output_loss: 2.1985 - aux_output_loss: 8.6133 - val_loss: 2.0734 - val_main_output_loss: 1.5840 - val_aux_output_loss: 6.4781
# Epoch 4/20
# 58/58 [==============================] - 0s 1ms/step - loss: 1.9641 - main_output_loss: 1.5242 - aux_output_loss: 5.9230 - val_loss: 1.5096 - val_main_output_loss: 1.1863 - val_aux_output_loss: 4.4195
# Epoch 5/20
# ...

# %%
total_loss, main_loss, aux_loss = model.evaluate(
    [X_test_A, X_test_B], [y_test, y_test])
y_pred_main, y_pred_aux = model.predict([X_new_A, X_new_B])
# Out:
# 26/26 [==============================] - 0s 880us/step - loss: 0.7877 - main_output_loss: 0.7321 - aux_output_loss: 1.2884

# %% [markdown]
# # The subclassing API
# The flip side of Sequential API and Functional API is that: it’s static. Some models involve loops, varying shapes, conditional branching, and other dynamic behaviors. For such cases, the Subclassing API allows a more imperative programming style.
#
# Simply subclass the Model class, create the layers you need in the constructor, and use them to perform the computations you want in the call() method. For example, creating an instance of the following WideAndDeepModel class gives us an equivalent model to the one we just built with the Functional API.

# %%
class WideAndDeepModel(keras.models.Model):
    def __init__(self, units=30, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.hidden1 = keras.layers.Dense(units, activation=activation)
        self.hidden2 = keras.layers.Dense(units, activation=activation)
        self.main_output = keras.layers.Dense(1)
        self.aux_output = keras.layers.Dense(1)
        
    def call(self, inputs):
        input_A, input_B = inputs
        hidden1 = self.hidden1(input_B)
        hidden2 = self.hidden2(hidden1)
        concat = keras.layers.concatenate([input_A, hidden2])
        main_output = self.main_output(concat)
        aux_output = self.aux_output(hidden2)
        return main_output, aux_output

model = WideAndDeepModel(30, activation="relu")

# %%
model.compile(loss="mse", loss_weights=[0.9, 0.1], optimizer=keras.optimizers.SGD(learning_rate=1e-3))
history = model.fit((X_train_A, X_train_B), (y_train, y_train), epochs=10,
                    validation_data=((X_valid_A, X_valid_B), (y_valid, y_valid)))
total_loss, main_loss, aux_loss = model.evaluate((X_test_A, X_test_B), (y_test, y_test))
y_pred_main, y_pred_aux = model.predict((X_new_A, X_new_B))
# Out:
# Epoch 1/10
# 58/58 [==============================] - 1s 3ms/step - loss: 13.2452 - output_1_loss: 12.7441 - output_2_loss: 17.7547 - val_loss: 5.9970 - val_output_1_loss: 5.1076 - val_output_2_loss: 14.0021
# Epoch 2/10
# 58/58 [==============================] - 0s 2ms/step - loss: 4.8257 - output_1_loss: 3.8754 - output_2_loss: 13.3788 - val_loss: 3.1488 - val_output_1_loss: 2.3943 - val_output_2_loss: 9.9385
# Epoch 3/10
# 58/58 [==============================] - 0s 2ms/step - loss: 3.0345 - output_1_loss: 2.3147 - output_2_loss: 9.5126 - val_loss: 2.2334 - val_output_1_loss: 1.6947 - val_output_2_loss: 7.0817
# Epoch 4/10
# 58/58 [==============================] - 0s 1ms/step - loss: 2.2090 - output_1_loss: 1.6919 - output_2_loss: 6.8627 - val_loss: 1.6998 - val_output_1_loss: 1.3279 - val_output_2_loss: 5.0471
# Epoch 5/10
# ...

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=[51]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(1)
])

# %%
model.compile(loss="mse", optimizer=keras.optimizers.SGD(learning_rate=1e-3))
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 58/58 [==============================] - 0s 2ms/step - loss: 12.9965 - val_loss: 5.9666
# Epoch 2/10
# 58/58 [==============================] - 0s 1ms/step - loss: 4.3320 - val_loss: 2.9021
# Epoch 3/10
# 58/58 [==============================] - 0s 1ms/step - loss: 2.5191 - val_loss: 1.8633
# Epoch 4/10
# 58/58 [==============================] - 0s 1ms/step - loss: 1.7836 - val_loss: 1.4012
# Epoch 5/10
# 58/58 [==============================] - 0s 1ms/step - loss: 1.4203 - val_loss: 1.1477
# Epoch 6/10
# 58/58 [==============================] - 0s 1ms/step - loss: 1.2053 - val_loss: 0.9886
# Epoch 7/10
# 58/58 [==============================] - 0s 1ms/step - loss: 1.0620 - val_loss: 0.8769
# Epoch 8/10
# 58/58 [==============================] - 0s 1ms/step - loss: 0.9592 - val_loss: 0.7964
# Epoch 9/10
# 58/58 [==============================] - 0s 1ms/step - loss: 0.8810 - val_loss: 0.7338
# Epoch 10/10
# ...

# %%
model.predict(X_new)
# Out:
# array([[6.629818 ],
#        [5.6203737],
#        [4.253439 ]], dtype=float32)
